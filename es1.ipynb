# %%
import numpy as np
import matplotlib.pyplot as plt


n = np.random.uniform(0,100,100000)
plt.hist(n)
# Out:
# (array([ 9893., 10000., 10111.,  9939., 10021., 10185., 10044.,  9994.,
#          9956.,  9857.]),
#  array([3.36042331e-03, 1.00026070e+01, 2.00018536e+01, 3.00011002e+01,
#         4.00003467e+01, 4.99995933e+01, 5.99988399e+01, 6.99980865e+01,
#         7.99973330e+01, 8.99965796e+01, 9.99958262e+01]),
#  <BarContainer object of 10 artists>)
